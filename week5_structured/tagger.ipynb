# %% [markdown]
# ### POS tagging with maximum entropy models (10 pts)
#
# In this task you will build a maximum entropy model for part-of-speech tagging. As the name suggests, our problem is all about converting a sequence of words into a sequence of part-of-speech tags.
# <img src=https://i.stack.imgur.com/6pdIT.png width=320>
#
#
# __Your man goal:__ implement the model from [the article you're given](W96-0213.pdf).
#
# Unlike previous tasks, this one gives you greater degree of freedom and less automated tests. We provide you with programming interface but nothing more.
#
# __A piece of advice:__ there's a lot of objects happening here. If you don't understand why some object is needed, find `def train` function and see how everything is linked together.

# %%
import collections

# %% [markdown]
# ### Part I: reading input data

# %%
# Data types:
# Word: str
# Sentence: list of str
TaggedWord = collections.namedtuple('TaggedWord', ['text', 'tag'])
# TaggedSentence: list of TaggedWord
# Tags: list of TaggedWord
# TagLattice: list of Tags

def read_tagged_sentences(path):
    """
    Read tagged sentences from CoNLL-U file and return array of TaggedSentence (array of lists of TaggedWord).
    """
    sentences = []
    sentence = []
    with open(path) as txt:
        for line in txt.readlines():
            if line.startswith('#'):
                continue
            if len(line) == 0 or len(line) == 1:
                sentences.append(sentence)
                sentence = []
                continue
            splited = line.split()
            sentence.append(TaggedWord(splited[1], splited[3]))
    return sentences
            

def write_tagged_sentence(tagged_sentence, f):
    """
    Write tagged sentence in CoNLL-U format to file-like object f.
    """
#     <YOUR CODE>
    pass

def read_tags(path):
    """
    Read a list of possible tags from file and return the list.
    """
    tags = []
    with open(path) as txt:
        tags = [word[:len(word) - 1] for word in txt.readlines()]
    return tags

# %%
read_tagged_sentences('./data/en-ud-train.conllu')
# Out:
# [[TaggedWord(text='Al', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='Zaman', tag='PROPN'),
#   TaggedWord(text=':', tag='PUNCT'),
#   TaggedWord(text='American', tag='ADJ'),
#   TaggedWord(text='forces', tag='NOUN'),
#   TaggedWord(text='killed', tag='VERB'),
#   TaggedWord(text='Shaikh', tag='PROPN'),
#   TaggedWord(text='Abdullah', tag='PROPN'),
#   TaggedWord(text='al', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='Ani', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='preacher', tag='NOUN'),
#   TaggedWord(text='at', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='mosque', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='town', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='Qaim', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='near', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Syrian', tag='ADJ'),
#   TaggedWord(text='border', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='[', tag='PUNCT'),
#   TaggedWord(text='This', tag='DET'),
#   TaggedWord(text='killing', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='respected', tag='ADJ'),
#   TaggedWord(text='cleric', tag='NOUN'),
#   TaggedWord(text='will', tag='AUX'),
#   TaggedWord(text='be', tag='AUX'),
#   TaggedWord(text='causing', tag='VERB'),
#   TaggedWord(text='us', tag='PRON'),
#   TaggedWord(text='trouble', tag='NOUN'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='years', tag='NOUN'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='come', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT'),
#   TaggedWord(text=']', tag='PUNCT')],
#  [TaggedWord(text='DPA', tag='PROPN'),
#   TaggedWord(text=':', tag='PUNCT'),
#   TaggedWord(text='Iraqi', tag='ADJ'),
#   TaggedWord(text='authorities', tag='NOUN'),
#   TaggedWord(text='announced', tag='VERB'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='had', tag='AUX'),
#   TaggedWord(text='busted', tag='VERB'),
#   TaggedWord(text='up', tag='ADP'),
#   TaggedWord(text='3', tag='NUM'),
#   TaggedWord(text='terrorist', tag='ADJ'),
#   TaggedWord(text='cells', tag='NOUN'),
#   TaggedWord(text='operating', tag='VERB'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Baghdad', tag='PROPN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Two', tag='NUM'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='them', tag='PRON'),
#   TaggedWord(text='were', tag='AUX'),
#   TaggedWord(text='being', tag='AUX'),
#   TaggedWord(text='run', tag='VERB'),
#   TaggedWord(text='by', tag='ADP'),
#   TaggedWord(text='2', tag='NUM'),
#   TaggedWord(text='officials', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Ministry', tag='PROPN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Interior', tag='PROPN'),
#   TaggedWord(text='!', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='MoI', tag='PROPN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Iraq', tag='PROPN'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='equivalent', tag='ADJ'),
#   TaggedWord(text='to', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='US', tag='PROPN'),
#   TaggedWord(text='FBI', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='so', tag='ADV'),
#   TaggedWord(text='this', tag='PRON'),
#   TaggedWord(text='would', tag='AUX'),
#   TaggedWord(text='be', tag='VERB'),
#   TaggedWord(text='like', tag='SCONJ'),
#   TaggedWord(text='having', tag='VERB'),
#   TaggedWord(text='J.', tag='PROPN'),
#   TaggedWord(text='Edgar', tag='PROPN'),
#   TaggedWord(text='Hoover', tag='PROPN'),
#   TaggedWord(text='unwittingly', tag='ADV'),
#   TaggedWord(text='employ', tag='VERB'),
#   TaggedWord(text='at', tag='ADP'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='high', tag='ADJ'),
#   TaggedWord(text='level', tag='NOUN'),
#   TaggedWord(text='members', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Weathermen', tag='PROPN'),
#   TaggedWord(text='bombers', tag='NOUN'),
#   TaggedWord(text='back', tag='ADV'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='1960s', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='third', tag='ADJ'),
#   TaggedWord(text='was', tag='AUX'),
#   TaggedWord(text='being', tag='AUX'),
#   TaggedWord(text='run', tag='VERB'),
#   TaggedWord(text='by', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='head', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='an', tag='DET'),
#   TaggedWord(text='investment', tag='NOUN'),
#   TaggedWord(text='firm', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='You', tag='PRON'),
#   TaggedWord(text='wonder', tag='VERB'),
#   TaggedWord(text='if', tag='SCONJ'),
#   TaggedWord(text='he', tag='PRON'),
#   TaggedWord(text='was', tag='AUX'),
#   TaggedWord(text='manipulating', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='market', tag='NOUN'),
#   TaggedWord(text='with', tag='ADP'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='bombing', tag='NOUN'),
#   TaggedWord(text='targets', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='cells', tag='NOUN'),
#   TaggedWord(text='were', tag='AUX'),
#   TaggedWord(text='operating', tag='VERB'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Ghazaliyah', tag='PROPN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='al', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='Jihad', tag='PROPN'),
#   TaggedWord(text='districts', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='capital', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Although', tag='SCONJ'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='announcement', tag='NOUN'),
#   TaggedWord(text='was', tag='AUX'),
#   TaggedWord(text='probably', tag='ADV'),
#   TaggedWord(text='made', tag='VERB'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='show', tag='VERB'),
#   TaggedWord(text='progress', tag='NOUN'),
#   TaggedWord(text='in', tag='SCONJ'),
#   TaggedWord(text='identifying', tag='VERB'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='breaking', tag='VERB'),
#   TaggedWord(text='up', tag='ADP'),
#   TaggedWord(text='terror', tag='NOUN'),
#   TaggedWord(text='cells', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='I', tag='PRON'),
#   TaggedWord(text='do', tag='AUX'),
#   TaggedWord(text="n't", tag='PART'),
#   TaggedWord(text='find', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='news', tag='NOUN'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Baathists', tag='PROPN'),
#   TaggedWord(text='continue', tag='VERB'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='penetrate', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Iraqi', tag='ADJ'),
#   TaggedWord(text='government', tag='NOUN'),
#   TaggedWord(text='very', tag='ADV'),
#   TaggedWord(text='hopeful', tag='ADJ'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='It', tag='PRON'),
#   TaggedWord(text='reminds', tag='VERB'),
#   TaggedWord(text='me', tag='PRON'),
#   TaggedWord(text='too', tag='ADV'),
#   TaggedWord(text='much', tag='ADV'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='ARVN', tag='PROPN'),
#   TaggedWord(text='officers', tag='NOUN'),
#   TaggedWord(text='who', tag='PRON'),
#   TaggedWord(text='were', tag='AUX'),
#   TaggedWord(text='secretly', tag='ADV'),
#   TaggedWord(text='working', tag='VERB'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='other', tag='ADJ'),
#   TaggedWord(text='side', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Vietnam', tag='PROPN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Al', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='Zaman', tag='PROPN'),
#   TaggedWord(text=':', tag='PUNCT'),
#   TaggedWord(text='Guerrillas', tag='NOUN'),
#   TaggedWord(text='killed', tag='VERB'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='member', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Kurdistan', tag='PROPN'),
#   TaggedWord(text='Democratic', tag='PROPN'),
#   TaggedWord(text='Party', tag='PROPN'),
#   TaggedWord(text='after', tag='SCONJ'),
#   TaggedWord(text='kidnapping', tag='VERB'),
#   TaggedWord(text='him', tag='PRON'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Mosul', tag='PROPN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='police', tag='NOUN'),
#   TaggedWord(text='commander', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='Ninevah', tag='PROPN'),
#   TaggedWord(text='Province', tag='PROPN'),
#   TaggedWord(text='announced', tag='VERB'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='bombings', tag='NOUN'),
#   TaggedWord(text='had', tag='AUX'),
#   TaggedWord(text='declined', tag='VERB'),
#   TaggedWord(text='80', tag='NUM'),
#   TaggedWord(text='percent', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Mosul', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='whereas', tag='SCONJ'),
#   TaggedWord(text='there', tag='PRON'),
#   TaggedWord(text='had', tag='AUX'),
#   TaggedWord(text='been', tag='VERB'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='big', tag='ADJ'),
#   TaggedWord(text='jump', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='number', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='kidnappings', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='On', tag='ADP'),
#   TaggedWord(text='Wednesday', tag='PROPN'),
#   TaggedWord(text='guerrillas', tag='NOUN'),
#   TaggedWord(text='had', tag='AUX'),
#   TaggedWord(text='kidnapped', tag='VERB'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='cosmetic', tag='ADJ'),
#   TaggedWord(text='surgeon', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='wife', tag='NOUN'),
#   TaggedWord(text='while', tag='SCONJ'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='were', tag='AUX'),
#   TaggedWord(text='on', tag='ADP'),
#   TaggedWord(text='their', tag='PRON'),
#   TaggedWord(text='way', tag='NOUN'),
#   TaggedWord(text='home', tag='ADV'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='In', tag='ADP'),
#   TaggedWord(text='Suwayrah', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='Kut', tag='PROPN'),
#   TaggedWord(text='Province', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='two', tag='NUM'),
#   TaggedWord(text='car', tag='NOUN'),
#   TaggedWord(text='bombs', tag='NOUN'),
#   TaggedWord(text='were', tag='AUX'),
#   TaggedWord(text='discovered', tag='VERB'),
#   TaggedWord(text='before', tag='SCONJ'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='could', tag='AUX'),
#   TaggedWord(text='be', tag='AUX'),
#   TaggedWord(text='detonated', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='(', tag='PUNCT'),
#   TaggedWord(text='Kut', tag='PROPN'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='southeastern', tag='ADJ'),
#   TaggedWord(text='Iraq', tag='PROPN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='has', tag='VERB'),
#   TaggedWord(text='an', tag='DET'),
#   TaggedWord(text='overwhelmingly', tag='ADV'),
#   TaggedWord(text='Shiite', tag='ADJ'),
#   TaggedWord(text='population', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='who', tag='PRON'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='on', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='lookout', tag='NOUN'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='Baathist', tag='PROPN'),
#   TaggedWord(text='saboteurs', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='willingly', tag='ADV'),
#   TaggedWord(text='turn', tag='VERB'),
#   TaggedWord(text='them', tag='PRON'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='This', tag='DET'),
#   TaggedWord(text='willingness', tag='NOUN'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='main', tag='ADJ'),
#   TaggedWord(text='difference', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='number', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='bombings', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='south', tag='NOUN'),
#   TaggedWord(text='as', tag='SCONJ'),
#   TaggedWord(text='opposed', tag='VERB'),
#   TaggedWord(text='to', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='center', tag='NOUN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='north', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='country', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT'),
#   TaggedWord(text=')', tag='PUNCT')],
#  [TaggedWord(text='In', tag='ADP'),
#   TaggedWord(text='Baghdad', tag='PROPN'),
#   TaggedWord(text='Kadhim', tag='PROPN'),
#   TaggedWord(text='Talal', tag='PROPN'),
#   TaggedWord(text='Husain', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='assistant', tag='ADJ'),
#   TaggedWord(text='dean', tag='NOUN'),
#   TaggedWord(text='at', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='School', tag='PROPN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='Education', tag='PROPN'),
#   TaggedWord(text='at', tag='ADP'),
#   TaggedWord(text='Mustansiriyah', tag='PROPN'),
#   TaggedWord(text='University', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='was', tag='AUX'),
#   TaggedWord(text='assassinated', tag='VERB'),
#   TaggedWord(text='with', tag='ADP'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='driver', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Salikh', tag='PROPN'),
#   TaggedWord(text='district', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Guerrillas', tag='NOUN'),
#   TaggedWord(text='killed', tag='VERB'),
#   TaggedWord(text='an', tag='DET'),
#   TaggedWord(text='engineer', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='Asi', tag='PROPN'),
#   TaggedWord(text='Ali', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='from', tag='ADP'),
#   TaggedWord(text='Tikrit', tag='PROPN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='They', tag='PRON'),
#   TaggedWord(text='also', tag='ADV'),
#   TaggedWord(text='killed', tag='VERB'),
#   TaggedWord(text='Shaikh', tag='PROPN'),
#   TaggedWord(text='Hamid', tag='PROPN'),
#   TaggedWord(text="'Akkab", tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='clan', tag='NOUN'),
#   TaggedWord(text='elder', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='branch', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Dulaim', tag='PROPN'),
#   TaggedWord(text='tribe', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Tikrit', tag='PROPN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='His', tag='PRON'),
#   TaggedWord(text='mother', tag='NOUN'),
#   TaggedWord(text='was', tag='AUX'),
#   TaggedWord(text='also', tag='ADV'),
#   TaggedWord(text='killed', tag='VERB'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='attack', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Two', tag='NUM'),
#   TaggedWord(text='other', tag='ADJ'),
#   TaggedWord(text='Dulaim', tag='PROPN'),
#   TaggedWord(text='leaders', tag='NOUN'),
#   TaggedWord(text='have', tag='AUX'),
#   TaggedWord(text='been', tag='AUX'),
#   TaggedWord(text='killed', tag='VERB'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='past', tag='ADJ'),
#   TaggedWord(text='week', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='half', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Guerrillas', tag='NOUN'),
#   TaggedWord(text='near', tag='ADP'),
#   TaggedWord(text='Hawijah', tag='PROPN'),
#   TaggedWord(text='launched', tag='VERB'),
#   TaggedWord(text='an', tag='DET'),
#   TaggedWord(text='attack', tag='NOUN'),
#   TaggedWord(text='that', tag='PRON'),
#   TaggedWord(text='left', tag='VERB'),
#   TaggedWord(text='6', tag='NUM'),
#   TaggedWord(text='dead', tag='ADJ'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='including', tag='VERB'),
#   TaggedWord(text='4', tag='NUM'),
#   TaggedWord(text='Iraqi', tag='ADJ'),
#   TaggedWord(text='soldiers', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='One', tag='NUM'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='them', tag='PRON'),
#   TaggedWord(text='was', tag='AUX'),
#   TaggedWord(text='from', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Jubur', tag='PROPN'),
#   TaggedWord(text='tribe', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='was', tag='AUX'),
#   TaggedWord(text='deputy', tag='NOUN'),
#   TaggedWord(text='commander', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Hawijah', tag='PROPN'),
#   TaggedWord(text='garrison', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Two', tag='NUM'),
#   TaggedWord(text='hundred', tag='NUM'),
#   TaggedWord(text='members', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Batawi', tag='PROPN'),
#   TaggedWord(text='clan', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Dulaim', tag='PROPN'),
#   TaggedWord(text='demonstrated', tag='VERB'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Baghdad', tag='PROPN'),
#   TaggedWord(text='on', tag='ADP'),
#   TaggedWord(text='Friday', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='protesting', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='killing', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='their', tag='PRON'),
#   TaggedWord(text='clan', tag='NOUN'),
#   TaggedWord(text='elder', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='Shaikh', tag='PROPN'),
#   TaggedWord(text='Kadhim', tag='PROPN'),
#   TaggedWord(text='Sarhid', tag='PROPN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='4', tag='NUM'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='sons', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='by', tag='ADP'),
#   TaggedWord(text='gunmen', tag='NOUN'),
#   TaggedWord(text='wearing', tag='VERB'),
#   TaggedWord(text='Iraqi', tag='ADJ'),
#   TaggedWord(text='army', tag='NOUN'),
#   TaggedWord(text='uniforms', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='(', tag='PUNCT'),
#   TaggedWord(text='This', tag='PRON'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='largely', tag='ADV'),
#   TaggedWord(text='Sunni', tag='ADJ'),
#   TaggedWord(text='Arab', tag='ADJ'),
#   TaggedWord(text='clan', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='some', tag='DET'),
#   TaggedWord(text='Sunni', tag='ADJ'),
#   TaggedWord(text='observers', tag='NOUN'),
#   TaggedWord(text='have', tag='AUX'),
#   TaggedWord(text='accused', tag='VERB'),
#   TaggedWord(text='Shiite', tag='ADJ'),
#   TaggedWord(text='elements', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='government', tag='NOUN'),
#   TaggedWord(text='of', tag='SCONJ'),
#   TaggedWord(text='being', tag='AUX'),
#   TaggedWord(text='behind', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='assassination', tag='NOUN'),
#   TaggedWord(text=';', tag='PUNCT'),
#   TaggedWord(text='it', tag='PRON'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='more', tag='ADV'),
#   TaggedWord(text='likely', tag='ADV'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='work', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='Sunni', tag='ADJ'),
#   TaggedWord(text='Arab', tag='ADJ'),
#   TaggedWord(text='guerrillas', tag='NOUN'),
#   TaggedWord(text='punishing', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Batawi', tag='PROPN'),
#   TaggedWord(text='leaders', tag='NOUN'),
#   TaggedWord(text='for', tag='SCONJ'),
#   TaggedWord(text='cooperating', tag='VERB'),
#   TaggedWord(text='with', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Dec.', tag='PROPN'),
#   TaggedWord(text='15', tag='NUM'),
#   TaggedWord(text='elections', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT'),
#   TaggedWord(text=')', tag='PUNCT')],
#  [TaggedWord(text='Al', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='Zaman', tag='PROPN'),
#   TaggedWord(text=':', tag='PUNCT'),
#   TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='Iraqi', tag='ADJ'),
#   TaggedWord(text='High', tag='PROPN'),
#   TaggedWord(text='Electoral', tag='PROPN'),
#   TaggedWord(text='Commission', tag='PROPN'),
#   TaggedWord(text='on', tag='ADP'),
#   TaggedWord(text='Friday', tag='PROPN'),
#   TaggedWord(text='denied', tag='VERB'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='request', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Debaathification', tag='PROPN'),
#   TaggedWord(text='Commission', tag='PROPN'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='exclude', tag='VERB'),
#   TaggedWord(text='51', tag='NUM'),
#   TaggedWord(text='individuals', tag='NOUN'),
#   TaggedWord(text='from', tag='SCONJ'),
#   TaggedWord(text='running', tag='VERB'),
#   TaggedWord(text='on', tag='ADP'),
#   TaggedWord(text='party', tag='NOUN'),
#   TaggedWord(text='lists', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Dec.', tag='PROPN'),
#   TaggedWord(text='15', tag='NUM'),
#   TaggedWord(text='elections', tag='NOUN'),
#   TaggedWord(text='on', tag='ADP'),
#   TaggedWord(text='grounds', tag='NOUN'),
#   TaggedWord(text='of', tag='SCONJ'),
#   TaggedWord(text='having', tag='AUX'),
#   TaggedWord(text='been', tag='AUX'),
#   TaggedWord(text='sufficiently', tag='ADV'),
#   TaggedWord(text='involved', tag='ADJ'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Baath', tag='PROPN'),
#   TaggedWord(text='activities', tag='NOUN'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='warrant', tag='VERB'),
#   TaggedWord(text='their', tag='PRON'),
#   TaggedWord(text='being', tag='AUX'),
#   TaggedWord(text='excluded', tag='VERB'),
#   TaggedWord(text='from', tag='ADP'),
#   TaggedWord(text='civil', tag='ADJ'),
#   TaggedWord(text='office', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='Commission', tag='NOUN'),
#   TaggedWord(text='said', tag='VERB'),
#   TaggedWord(text='it', tag='PRON'),
#   TaggedWord(text='had', tag='VERB'),
#   TaggedWord(text='no', tag='DET'),
#   TaggedWord(text='legal', tag='ADJ'),
#   TaggedWord(text='grounds', tag='NOUN'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='such', tag='DET'),
#   TaggedWord(text='an', tag='DET'),
#   TaggedWord(text='exclusion', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='This', tag='DET'),
#   TaggedWord(text='item', tag='NOUN'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='small', tag='ADJ'),
#   TaggedWord(text='one', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='easily', tag='ADV'),
#   TaggedWord(text='missed', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='But', tag='CCONJ'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='my', tag='PRON'),
#   TaggedWord(text='view', tag='NOUN'),
#   TaggedWord(text='it', tag='PRON'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='highly', tag='ADV'),
#   TaggedWord(text='significant', tag='ADJ'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='Debaathification', tag='PROPN'),
#   TaggedWord(text='Commission', tag='PROPN'),
#   TaggedWord(text='had', tag='AUX'),
#   TaggedWord(text='been', tag='AUX'),
#   TaggedWord(text='pushed', tag='VERB'),
#   TaggedWord(text='by', tag='ADP'),
#   TaggedWord(text='Ahmad', tag='PROPN'),
#   TaggedWord(text='Chalabi', tag='PROPN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='Iraqi', tag='PROPN'),
#   TaggedWord(text='National', tag='PROPN'),
#   TaggedWord(text='Congress', tag='PROPN'),
#   TaggedWord(text='very', tag='ADV'),
#   TaggedWord(text='hard', tag='ADV'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='had', tag='AUX'),
#   TaggedWord(text='pushed', tag='VERB'),
#   TaggedWord(text='many', tag='ADJ'),
#   TaggedWord(text='Sunni', tag='ADJ'),
#   TaggedWord(text='Arabs', tag='PROPN'),
#   TaggedWord(text='into', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='arms', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='guerrillas', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Chalabi', tag='PROPN'),
#   TaggedWord(text='has', tag='AUX'),
#   TaggedWord(text='been', tag='AUX'),
#   TaggedWord(text='increasingly', tag='ADV'),
#   TaggedWord(text='marginalized', tag='VERB'),
#   TaggedWord(text='within', tag='ADP'),
#   TaggedWord(text='Iraq', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='however', tag='ADV'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='despite', tag='ADP'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='ties', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='clientelage', tag='NOUN'),
#   TaggedWord(text='with', tag='ADP'),
#   TaggedWord(text='Washington', tag='PROPN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='Tehran', tag='PROPN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='He', tag='PRON'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='no', tag='ADV'),
#   TaggedWord(text='longer', tag='ADV'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='dominant', tag='ADJ'),
#   TaggedWord(text='Shiite', tag='ADJ'),
#   TaggedWord(text='list', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='United', tag='PROPN'),
#   TaggedWord(text='Iraqi', tag='PROPN'),
#   TaggedWord(text='Alliance', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='wo', tag='AUX'),
#   TaggedWord(text="n't", tag='PART'),
#   TaggedWord(text='have', tag='VERB'),
#   TaggedWord(text='many', tag='ADJ'),
#   TaggedWord(text='seats', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='new', tag='ADJ'),
#   TaggedWord(text='parliament', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Some', tag='DET'),
#   TaggedWord(text='2,000', tag='NUM'),
#   TaggedWord(text='junior', tag='ADJ'),
#   TaggedWord(text='officers', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='old', tag='ADJ'),
#   TaggedWord(text='Baath', tag='PROPN'),
#   TaggedWord(text='army', tag='NOUN'),
#   TaggedWord(text='have', tag='AUX'),
#   TaggedWord(text='been', tag='AUX'),
#   TaggedWord(text='recalled', tag='VERB'),
#   TaggedWord(text='to', tag='ADP'),
#   TaggedWord(text='duty', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='recent', tag='ADJ'),
#   TaggedWord(text='months', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='something', tag='PRON'),
#   TaggedWord(text='Chalabi', tag='PROPN'),
#   TaggedWord(text='would', tag='AUX'),
#   TaggedWord(text='have', tag='AUX'),
#   TaggedWord(text='blocked', tag='VERB'),
#   TaggedWord(text='if', tag='SCONJ'),
#   TaggedWord(text='he', tag='PRON'),
#   TaggedWord(text='could', tag='AUX'),
#   TaggedWord(text='have', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Now', tag='ADV'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Electoral', tag='PROPN'),
#   TaggedWord(text='Commission', tag='PROPN'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='refusing', tag='VERB'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='punish', tag='VERB'),
#   TaggedWord(text='people', tag='NOUN'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='mere', tag='ADJ'),
#   TaggedWord(text='past', tag='ADJ'),
#   TaggedWord(text='Baath', tag='PROPN'),
#   TaggedWord(text='Party', tag='PROPN'),
#   TaggedWord(text='membership', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='situation', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Iraq', tag='PROPN'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='only', tag='ADV'),
#   TaggedWord(text='going', tag='VERB'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='get', tag='VERB'),
#   TaggedWord(text='better', tag='ADJ'),
#   TaggedWord(text='this', tag='DET'),
#   TaggedWord(text='way', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='If', tag='SCONJ'),
#   TaggedWord(text='someone', tag='PRON'),
#   TaggedWord(text='committed', tag='VERB'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='crime', tag='NOUN'),
#   TaggedWord(text='against', tag='ADP'),
#   TaggedWord(text='humanity', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='prosecute', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='person', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='If', tag='SCONJ'),
#   TaggedWord(text='he', tag='PRON'),
#   TaggedWord(text='or', tag='CCONJ'),
#   TaggedWord(text='she', tag='PRON'),
#   TaggedWord(text='did', tag='VERB'),
#   TaggedWord(text='not', tag='PART'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='then', tag='ADV'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='should', tag='AUX'),
#   TaggedWord(text='have', tag='VERB'),
#   TaggedWord(text='all', tag='DET'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='same', tag='ADJ'),
#   TaggedWord(text='rights', tag='NOUN'),
#   TaggedWord(text='as', tag='ADP'),
#   TaggedWord(text='other', tag='ADJ'),
#   TaggedWord(text='Iraqis', tag='PROPN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Al', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='Sharq', tag='PROPN'),
#   TaggedWord(text='al', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='Awsat', tag='PROPN'),
#   TaggedWord(text='reports', tag='VERB'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='key', tag='ADJ'),
#   TaggedWord(text='eyewitness', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='trial', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='Saddam', tag='PROPN'),
#   TaggedWord(text='Hussein', tag='PROPN'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='1982', tag='NUM'),
#   TaggedWord(text='massacre', tag='NOUN'),
#   TaggedWord(text='at', tag='ADP'),
#   TaggedWord(text='Dujail', tag='PROPN'),
#   TaggedWord(text='has', tag='AUX'),
#   TaggedWord(text='died', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='A', tag='DET'),
#   TaggedWord(text='team', tag='NOUN'),
#   TaggedWord(text='from', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='court', tag='NOUN'),
#   TaggedWord(text='managed', tag='VERB'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='take', tag='VERB'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='deposition', tag='NOUN'),
#   TaggedWord(text='before', tag='SCONJ'),
#   TaggedWord(text='he', tag='PRON'),
#   TaggedWord(text='died', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='trial', tag='NOUN'),
#   TaggedWord(text='begins', tag='VERB'),
#   TaggedWord(text='again', tag='ADV'),
#   TaggedWord(text='Nov.', tag='PROPN'),
#   TaggedWord(text='28', tag='NUM'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='In', tag='ADP'),
#   TaggedWord(text='Baghdad', tag='PROPN'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='fighting', tag='NOUN'),
#   TaggedWord(text='still', tag='ADV'),
#   TaggedWord(text='continues', tag='VERB'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='several', tag='ADJ'),
#   TaggedWord(text='areas', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='mostly', tag='ADV'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Sadr', tag='PROPN'),
#   TaggedWord(text='city', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='Adhamiya', tag='PROPN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Baghdadis', tag='PROPN'),
#   TaggedWord(text='do', tag='AUX'),
#   TaggedWord(text="n't", tag='PART'),
#   TaggedWord(text='venture', tag='VERB'),
#   TaggedWord(text='much', tag='ADV'),
#   TaggedWord(text='out', tag='ADP'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='their', tag='PRON'),
#   TaggedWord(text='neighbourhoods', tag='NOUN'),
#   TaggedWord(text='any', tag='ADV'),
#   TaggedWord(text='more', tag='ADV'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='you', tag='PRON'),
#   TaggedWord(text='never', tag='ADV'),
#   TaggedWord(text='know', tag='VERB'),
#   TaggedWord(text='where', tag='ADV'),
#   TaggedWord(text='you', tag='PRON'),
#   TaggedWord(text='might', tag='AUX'),
#   TaggedWord(text='get', tag='VERB'),
#   TaggedWord(text='stuck', tag='ADJ'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='There', tag='PRON'),
#   TaggedWord(text='has', tag='AUX'),
#   TaggedWord(text='been', tag='VERB'),
#   TaggedWord(text='talk', tag='NOUN'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='night', tag='NOUN'),
#   TaggedWord(text='curfew', tag='NOUN'),
#   TaggedWord(text='might', tag='AUX'),
#   TaggedWord(text='be', tag='AUX'),
#   TaggedWord(text='implemented', tag='VERB'),
#   TaggedWord(text='again', tag='ADV'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='My', tag='PRON'),
#   TaggedWord(text='neighbourhood', tag='NOUN'),
#   TaggedWord(text='has', tag='AUX'),
#   TaggedWord(text='been', tag='AUX'),
#   TaggedWord(text='surrounded', tag='VERB'),
#   TaggedWord(text='by', tag='ADP'),
#   TaggedWord(text='American', tag='ADJ'),
#   TaggedWord(text='troops', tag='NOUN'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='three', tag='NUM'),
#   TaggedWord(text='days', tag='NOUN'),
#   TaggedWord(text='now', tag='ADV'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='helicopters', tag='NOUN'),
#   TaggedWord(text='have', tag='AUX'),
#   TaggedWord(text='been', tag='AUX'),
#   TaggedWord(text='circling', tag='VERB'),
#   TaggedWord(text='over', tag='ADP'),
#   TaggedWord(text='our', tag='PRON'),
#   TaggedWord(text='heads', tag='NOUN'),
#   TaggedWord(text='non-stop', tag='ADV'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Fedayeen', tag='NOUN'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='now', tag='ADV'),
#   TaggedWord(text='visible', tag='ADJ'),
#   TaggedWord(text='on', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='street', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='have', tag='AUX'),
#   TaggedWord(text='become', tag='VERB'),
#   TaggedWord(text='bolder', tag='ADJ'),
#   TaggedWord(text='than', tag='ADP'),
#   TaggedWord(text='ever', tag='ADV'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Yesterday', tag='NOUN'),
#   TaggedWord(text='there', tag='PRON'),
#   TaggedWord(text='were', tag='VERB'),
#   TaggedWord(text='tens', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='them', tag='PRON'),
#   TaggedWord(text='putting', tag='VERB'),
#   TaggedWord(text='road', tag='NOUN'),
#   TaggedWord(text='blocks', tag='NOUN'),
#   TaggedWord(text='on', tag='ADP'),
#   TaggedWord(text='our', tag='PRON'),
#   TaggedWord(text='street', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='setting', tag='VERB'),
#   TaggedWord(text='up', tag='ADP'),
#   TaggedWord(text='mortars', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='only', tag='ADV'),
#   TaggedWord(text='come', tag='VERB'),
#   TaggedWord(text='out', tag='ADV'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='open', tag='ADJ'),
#   TaggedWord(text='when', tag='ADV'),
#   TaggedWord(text='Americans', tag='PROPN'),
#   TaggedWord(text='leave', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='area', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='then', tag='ADV'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='start', tag='VERB'),
#   TaggedWord(text='firing', tag='VERB'),
#   TaggedWord(text='mortars', tag='NOUN'),
#   TaggedWord(text='indiscriminately', tag='ADV'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='shooting', tag='VERB'),
#   TaggedWord(text='their', tag='PRON'),
#   TaggedWord(text='AK', tag='NOUN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text="47's", tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='air', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='They', tag='PRON'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='setting', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='road', tag='NOUN'),
#   TaggedWord(text='blocks', tag='NOUN'),
#   TaggedWord(text='at', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='exact', tag='ADV'),
#   TaggedWord(text='same', tag='ADJ'),
#   TaggedWord(text='positions', tag='NOUN'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='were', tag='VERB'),
#   TaggedWord(text='during', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='war', tag='NOUN'),
#   TaggedWord(text='last', tag='ADJ'),
#   TaggedWord(text='year', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='which', tag='PRON'),
#   TaggedWord(text='indicates', tag='VERB'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='same', tag='ADJ'),
#   TaggedWord(text='people', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='And', tag='CCONJ'),
#   TaggedWord(text='there', tag='PRON'),
#   TaggedWord(text='is', tag='VERB'),
#   TaggedWord(text='nothing', tag='PRON'),
#   TaggedWord(text='we', tag='PRON'),
#   TaggedWord(text='can', tag='AUX'),
#   TaggedWord(text='do', tag='VERB'),
#   TaggedWord(text='about', tag='ADP'),
#   TaggedWord(text='it', tag='PRON'),
#   TaggedWord(text='really', tag='ADV'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='people', tag='NOUN'),
#   TaggedWord(text='who', tag='PRON'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='suggesting', tag='VERB'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='we', tag='PRON'),
#   TaggedWord(text='go', tag='VERB'),
#   TaggedWord(text='out', tag='ADV'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='fight', tag='VERB'),
#   TaggedWord(text='them', tag='PRON'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='living', tag='VERB'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='dream', tag='NOUN'),
#   TaggedWord(text='land', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Even', tag='ADV'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='IP', tag='PROPN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='ICDC', tag='PROPN'),
#   TaggedWord(text='have', tag='AUX'),
#   TaggedWord(text='abandoned', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='neighbourhood', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='those', tag='PRON'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='trained', tag='ADJ'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='armed', tag='ADJ'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='so', tag='ADV'),
#   TaggedWord(text='do', tag='AUX'),
#   TaggedWord(text="n't", tag='PART'),
#   TaggedWord(text='expect', tag='VERB'),
#   TaggedWord(text='scared', tag='ADJ'),
#   TaggedWord(text='civilians', tag='NOUN'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='do', tag='VERB'),
#   TaggedWord(text='anything', tag='PRON'),
#   TaggedWord(text='except', tag='SCONJ'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='hide', tag='VERB'),
#   TaggedWord(text='inside', tag='ADV'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='pray', tag='VERB'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='helicopter', tag='NOUN'),
#   TaggedWord(text='or', tag='CCONJ'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='tank', tag='NOUN'),
#   TaggedWord(text='does', tag='AUX'),
#   TaggedWord(text="n't", tag='PART'),
#   TaggedWord(text='bomb', tag='VERB'),
#   TaggedWord(text='them', tag='PRON'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='also', tag='ADV'),
#   TaggedWord(text='how', tag='ADV'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='American', tag='ADJ'),
#   TaggedWord(text='soldiers', tag='NOUN'),
#   TaggedWord(text='going', tag='VERB'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='distinguish', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='brave', tag='ADJ'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='valiant', tag='ADJ'),
#   TaggedWord(text='civilians', tag='NOUN'),
#   TaggedWord(text='from', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Fedayeen', tag='NOUN'),
#   TaggedWord(text='?', tag='PUNCT')],
#  [TaggedWord(text='Everyone', tag='PRON'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='apprehensive', tag='ADJ'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='there', tag='PRON'),
#   TaggedWord(text='is', tag='VERB'),
#   TaggedWord(text='some', tag='DET'),
#   TaggedWord(text='talk', tag='NOUN'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='April', tag='PROPN'),
#   TaggedWord(text='9th', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='10th', tag='NOUN'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='going', tag='VERB'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='be', tag='AUX'),
#   TaggedWord(text='bloody', tag='ADJ'),
#   TaggedWord(text='days', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Most', tag='ADJ'),
#   TaggedWord(text='people', tag='NOUN'),
#   TaggedWord(text='have', tag='AUX'),
#   TaggedWord(text="n't", tag='PART'),
#   TaggedWord(text='gone', tag='VERB'),
#   TaggedWord(text='to', tag='ADP'),
#   TaggedWord(text='work', tag='NOUN'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='last', tag='ADJ'),
#   TaggedWord(text='few', tag='ADJ'),
#   TaggedWord(text='days', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='although', tag='SCONJ'),
#   TaggedWord(text='it', tag='PRON'),
#   TaggedWord(text='seems', tag='VERB'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='rest', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='Baghdad', tag='PROPN'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text="'", tag='PUNCT'),
#   TaggedWord(text='normal', tag='ADJ'),
#   TaggedWord(text="'", tag='PUNCT'),
#   TaggedWord(text='(', tag='PUNCT'),
#   TaggedWord(text='if', tag='SCONJ'),
#   TaggedWord(text='you', tag='PRON'),
#   TaggedWord(text='can', tag='AUX'),
#   TaggedWord(text='define', tag='VERB'),
#   TaggedWord(text='what', tag='PRON'),
#   TaggedWord(text='normal', tag='NOUN'),
#   TaggedWord(text='is', tag='VERB'),
#   TaggedWord(text=')', tag='PUNCT'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='There', tag='PRON'),
#   TaggedWord(text='are', tag='VERB'),
#   TaggedWord(text='rumours', tag='NOUN'),
#   TaggedWord(text='about', tag='ADP'),
#   TaggedWord(text='preparations', tag='NOUN'),
#   TaggedWord(text='by', tag='ADP'),
#   TaggedWord(text='slum', tag='NOUN'),
#   TaggedWord(text='dwellers', tag='NOUN'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='another', tag='DET'),
#   TaggedWord(text='looting', tag='NOUN'),
#   TaggedWord(text='spree', tag='NOUN'),
#   TaggedWord(text='against', tag='ADP'),
#   TaggedWord(text='banks', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='governmental', tag='ADJ'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='public', tag='ADJ'),
#   TaggedWord(text='property', tag='NOUN'),
#   TaggedWord(text='similar', tag='ADJ'),
#   TaggedWord(text='to', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='one', tag='NOUN'),
#   TaggedWord(text='that', tag='PRON'),
#   TaggedWord(text='took', tag='VERB'),
#   TaggedWord(text='place', tag='NOUN'),
#   TaggedWord(text='last', tag='ADJ'),
#   TaggedWord(text='April', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='I', tag='PRON'),
#   TaggedWord(text='have', tag='AUX'),
#   TaggedWord(text='already', tag='ADV'),
#   TaggedWord(text='overheard', tag='VERB'),
#   TaggedWord(text='youngsters', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='my', tag='PRON'),
#   TaggedWord(text='neighbourhood', tag='NOUN'),
#   TaggedWord(text='joking', tag='VERB'),
#   TaggedWord(text='about', tag='ADP'),
#   TaggedWord(text='it', tag='PRON'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='saying', tag='VERB'),
#   TaggedWord(text='things', tag='NOUN'),
#   TaggedWord(text='like', tag='SCONJ'),
#   TaggedWord(text='"', tag='PUNCT'),
#   TaggedWord(text='This', tag='DET'),
#   TaggedWord(text='time', tag='NOUN'),
#   TaggedWord(text='we', tag='PRON'),
#   TaggedWord(text='will', tag='AUX'),
#   TaggedWord(text='be', tag='AUX'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='first', tag='ADJ'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='loot', tag='VERB'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='we', tag='PRON'),
#   TaggedWord(text='did', tag='AUX'),
#   TaggedWord(text="n't", tag='PART'),
#   TaggedWord(text='get', tag='VERB'),
#   TaggedWord(text='anything', tag='PRON'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='last', tag='ADJ'),
#   TaggedWord(text='time', tag='NOUN'),
#   TaggedWord(text='"', tag='PUNCT'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Mosques', tag='NOUN'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='calling', tag='VERB'),
#   TaggedWord(text='for', tag='SCONJ'),
#   TaggedWord(text='donating', tag='VERB'),
#   TaggedWord(text='blood', tag='NOUN'),
# ...
#   TaggedWord(text='relentless', tag='ADJ'),
#   TaggedWord(text='search', tag='NOUN'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='missing', tag='ADJ'),
#   TaggedWord(text='son', tag='NOUN'),
#   TaggedWord(text='led', tag='VERB'),
#   TaggedWord(text='him', tag='PRON'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='uncover', tag='VERB'),
#   TaggedWord(text='one', tag='NUM'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='most', tag='ADV'),
#   TaggedWord(text='shocking', tag='ADJ'),
#   TaggedWord(text='crimes', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='post-war', tag='ADJ'),
#   TaggedWord(text='Italy', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='tale', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='satanism', tag='PROPN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='violence', tag='NOUN'),
#   TaggedWord(text='that', tag='PRON'),
#   TaggedWord(text='has', tag='AUX'),
#   TaggedWord(text='gripped', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='country', tag='NOUN'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text='more', tag='ADJ'),
#   TaggedWord(text='than', tag='ADP'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='year', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='In', tag='ADP'),
#   TaggedWord(text='January', tag='PROPN'),
#   TaggedWord(text='1998', tag='NUM'),
#   TaggedWord(text='Fabio', tag='PROPN'),
#   TaggedWord(text='Tollis', tag='PROPN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='Chiara', tag='PROPN'),
#   TaggedWord(text='Marino', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='both', tag='ADV'),
#   TaggedWord(text='just', tag='ADV'),
#   TaggedWord(text='16', tag='NUM'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='disappeared', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='They', tag='PRON'),
#   TaggedWord(text='had', tag='AUX'),
#   TaggedWord(text='been', tag='AUX'),
#   TaggedWord(text='drinking', tag='VERB'),
#   TaggedWord(text='at', tag='ADP'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='pub', tag='NOUN'),
#   TaggedWord(text='called', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='Midnight', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='centre', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='heavy', tag='ADJ'),
#   TaggedWord(text='metal', tag='NOUN'),
#   TaggedWord(text='scene', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='Milan', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='never', tag='ADV'),
#   TaggedWord(text='came', tag='VERB'),
#   TaggedWord(text='home', tag='ADV'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='police', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='many', tag='ADJ'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='their', tag='PRON'),
#   TaggedWord(text='friends', tag='NOUN'),
#   TaggedWord(text='just', tag='ADV'),
#   TaggedWord(text='thought', tag='VERB'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='had', tag='AUX'),
#   TaggedWord(text='run', tag='VERB'),
#   TaggedWord(text='off', tag='ADV'),
#   TaggedWord(text='together', tag='ADV'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='But', tag='CCONJ'),
#   TaggedWord(text='their', tag='PRON'),
#   TaggedWord(text='parents', tag='NOUN'),
#   TaggedWord(text='refused', tag='VERB'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='accept', tag='VERB'),
#   TaggedWord(text='this', tag='PRON'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Michele', tag='PROPN'),
#   TaggedWord(text='Tollis', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='Fabio', tag='PROPN'),
#   TaggedWord(text="'s", tag='PART'),
#   TaggedWord(text='father', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='began', tag='VERB'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='attend', tag='VERB'),
#   TaggedWord(text='metal', tag='NOUN'),
#   TaggedWord(text='concerts', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='festivals', tag='NOUN'),
#   TaggedWord(text='across', tag='ADP'),
#   TaggedWord(text='Europe', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='handing', tag='VERB'),
#   TaggedWord(text='out', tag='ADP'),
#   TaggedWord(text='leaflets', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='quizzing', tag='VERB'),
#   TaggedWord(text='Fabio', tag='PROPN'),
#   TaggedWord(text="'s", tag='PART'),
#   TaggedWord(text='friends', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Fabio', tag='PROPN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='friends', tag='NOUN'),
#   TaggedWord(text='were', tag='AUX'),
#   TaggedWord(text='into', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='most', tag='ADV'),
#   TaggedWord(text='extreme', tag='ADJ'),
#   TaggedWord(text='forms', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='heavy', tag='ADJ'),
#   TaggedWord(text='metal', tag='NOUN'),
#   TaggedWord(text='music', tag='NOUN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='death', tag='NOUN'),
#   TaggedWord(text='metal', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='black', tag='ADJ'),
#   TaggedWord(text='metal', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='music', tag='NOUN'),
#   TaggedWord(text='obsessed', tag='ADJ'),
#   TaggedWord(text='with', tag='ADP'),
#   TaggedWord(text='images', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='murder', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='satanism', tag='PROPN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='role', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='this', tag='DET'),
#   TaggedWord(text='music', tag='NOUN'),
#   TaggedWord(text='is', tag='AUX'),
#   TaggedWord(text='central', tag='ADJ'),
#   TaggedWord(text='to', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='story', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='No', tag='DET'),
#   TaggedWord(text='one', tag='NOUN'),
#   TaggedWord(text='can', tag='AUX'),
#   TaggedWord(text='contradict', tag='VERB'),
#   TaggedWord(text='me', tag='PRON'),
#   TaggedWord(text='when', tag='ADV'),
#   TaggedWord(text='I', tag='PRON'),
#   TaggedWord(text='say', tag='VERB'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='heavy', tag='ADJ'),
#   TaggedWord(text='metal', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='satanism', tag='PROPN'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='closely', tag='ADV'),
#   TaggedWord(text='linked', tag='VERB')],
#  [TaggedWord(text='Michele', tag='PROPN'),
#   TaggedWord(text='Tollis', tag='PROPN')],
#  [TaggedWord(text='It', tag='PRON'),
#   TaggedWord(text='emerged', tag='VERB'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='Chiara', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='girl', tag='NOUN'),
#   TaggedWord(text='who', tag='PRON'),
#   TaggedWord(text='disappeared', tag='VERB'),
#   TaggedWord(text='with', tag='ADP'),
#   TaggedWord(text='Fabio', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='had', tag='VERB'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='collection', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='satanic', tag='ADJ'),
#   TaggedWord(text='literature', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='paraphernalia', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='her', tag='PRON'),
#   TaggedWord(text='bedroom', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='During', tag='ADP'),
#   TaggedWord(text='this', tag='DET'),
#   TaggedWord(text='search', tag='NOUN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='Michele', tag='PROPN'),
#   TaggedWord(text='Tollis', tag='PROPN'),
#   TaggedWord(text='became', tag='VERB'),
#   TaggedWord(text='convinced', tag='ADJ'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='satanism', tag='PROPN'),
#   TaggedWord(text='had', tag='VERB'),
#   TaggedWord(text='something', tag='PRON'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='do', tag='VERB'),
#   TaggedWord(text='with', tag='ADP'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='son', tag='NOUN'),
#   TaggedWord(text="'s", tag='PART'),
#   TaggedWord(text='disappearance', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='"', tag='PUNCT'),
#   TaggedWord(text='No', tag='DET'),
#   TaggedWord(text='one', tag='NOUN'),
#   TaggedWord(text='can', tag='AUX'),
#   TaggedWord(text='contradict', tag='VERB'),
#   TaggedWord(text='me', tag='PRON'),
#   TaggedWord(text='when', tag='ADV'),
#   TaggedWord(text='I', tag='PRON'),
#   TaggedWord(text='say', tag='VERB'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='heavy', tag='ADJ'),
#   TaggedWord(text='metal', tag='NOUN'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='satanism', tag='PROPN'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='closely', tag='ADV'),
#   TaggedWord(text='linked', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='They', tag='PRON'),
#   TaggedWord(text="'re", tag='AUX'),
#   TaggedWord(text='inseparable', tag='ADJ'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='"', tag='PUNCT'),
#   TaggedWord(text='he', tag='PRON'),
#   TaggedWord(text='says', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Yeah', tag='INTJ'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='I', tag='PRON'),
#   TaggedWord(text='think', tag='VERB'),
#   TaggedWord(text='Jeff', tag='PROPN'),
#   TaggedWord(text='wrote', tag='VERB'),
#   TaggedWord(text='on', tag='ADP'),
#   TaggedWord(text='one', tag='NUM'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='his', tag='PRON'),
#   TaggedWord(text='posts', tag='NOUN'),
#   TaggedWord(text='here', tag='ADV'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='past', tag='ADJ'),
#   TaggedWord(text='several', tag='ADJ'),
#   TaggedWord(text='months', tag='NOUN'),
#   TaggedWord(text=':', tag='PUNCT'),
#   TaggedWord(text='"', tag='PUNCT'),
#   TaggedWord(text='To', tag='ADP'),
#   TaggedWord(text='hell', tag='NOUN'),
#   TaggedWord(text='with', tag='ADP'),
#   TaggedWord(text='death', tag='NOUN'),
#   TaggedWord(text='"', tag='PUNCT'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='I', tag='PRON'),
#   TaggedWord(text='wholly', tag='ADV'),
#   TaggedWord(text='agree', tag='VERB'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='would', tag='AUX'),
#   TaggedWord(text='expand', tag='VERB'),
#   TaggedWord(text='that', tag='DET'),
#   TaggedWord(text='statement', tag='NOUN'),
#   TaggedWord(text='to', tag='PART'),
#   TaggedWord(text='include', tag='VERB'),
#   TaggedWord(text=':', tag='PUNCT'),
#   TaggedWord(text='"', tag='PUNCT'),
#   TaggedWord(text='To', tag='ADP'),
#   TaggedWord(text='hell', tag='NOUN'),
#   TaggedWord(text='with', tag='ADP'),
#   TaggedWord(text='death', tag='NOUN'),
#   TaggedWord(text='metal', tag='NOUN'),
#   TaggedWord(text='"', tag='PUNCT'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='The', tag='DET'),
#   TaggedWord(text='freaky', tag='ADJ'),
#   TaggedWord(text='thing', tag='NOUN'),
#   TaggedWord(text='here', tag='ADV'),
#   TaggedWord(text='is', tag='VERB'),
#   TaggedWord(text='that', tag='SCONJ'),
#   TaggedWord(text='these', tag='DET'),
#   TaggedWord(text='bozos', tag='NOUN'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='seriously', tag='ADV'),
#   TaggedWord(text='claiming', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='moral', tag='ADJ'),
#   TaggedWord(text='high', tag='ADJ'),
#   TaggedWord(text='ground', tag='NOUN'),
#   TaggedWord(text='?', tag='PUNCT'),
#   TaggedWord(text='?', tag='PUNCT'),
#   TaggedWord(text='?', tag='PUNCT'),
#   TaggedWord(text='?', tag='PUNCT'),
#   TaggedWord(text='?', tag='PUNCT')],
#  [TaggedWord(text='Talk', tag='VERB'),
#   TaggedWord(text='about', tag='ADP'),
#   TaggedWord(text='a', tag='DET'),
#   TaggedWord(text='beat', tag='VERB'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='your', tag='PRON'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='head', tag='NOUN'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='against', tag='ADP'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='-', tag='PUNCT'),
#   TaggedWord(text='wall', tag='NOUN'),
#   TaggedWord(text='moment', tag='NOUN'),
#   TaggedWord(text='!', tag='PUNCT')],
#  [TaggedWord(text='And', tag='CCONJ'),
#   TaggedWord(text='for', tag='ADP'),
#   TaggedWord(text="'", tag='PUNCT'),
#   TaggedWord(text='Smartwolf', tag='PROPN'),
#   TaggedWord(text="'", tag='PUNCT'),
#   TaggedWord(text='above', tag='ADV'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='think', tag='VERB'),
#   TaggedWord(text='about', tag='ADP'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='inversion', tag='NOUN'),
#   TaggedWord(text='principle', tag='NOUN'),
#   TaggedWord(text='being', tag='AUX'),
#   TaggedWord(text='employed', tag='VERB'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='They', tag='PRON'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='doing', tag='VERB'),
#   TaggedWord(text='it', tag='PRON'),
#   TaggedWord(text='deliberately', tag='ADV'),
#   TaggedWord(text='.', tag='PUNCT')],
#  [TaggedWord(text='Do', tag='AUX'),
#   TaggedWord(text='you', tag='PRON'),
#   TaggedWord(text='really', tag='ADV'),
#   TaggedWord(text='think', tag='VERB'),
#   TaggedWord(text='GWB', tag='PROPN'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='and', tag='CCONJ'),
#   TaggedWord(text='neocons', tag='NOUN'),
#   TaggedWord(text='in', tag='ADP'),
#   TaggedWord(text='general', tag='ADJ'),
#   TaggedWord(text='are', tag='AUX'),
#   TaggedWord(text='representative', tag='ADJ'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='true', tag='ADJ'),
#   TaggedWord(text='followers', tag='NOUN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='Jesus', tag='PROPN'),
#   TaggedWord(text='of', tag='ADP'),
#   TaggedWord(text='Nazareth', tag='PROPN'),
#   TaggedWord(text='?', tag='PUNCT')],
#  [TaggedWord(text='(', tag='PUNCT'),
#   TaggedWord(text='I', tag='PRON'),
#   TaggedWord(text='know', tag='VERB'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='ignorant', tag='ADJ'),
#   TaggedWord(text='question', tag='NOUN'),
#   TaggedWord(text=')', tag='PUNCT'),
#   TaggedWord(text='Then', tag='ADV'),
#   TaggedWord(text='why', tag='ADV'),
#   TaggedWord(text='call', tag='VERB'),
#   TaggedWord(text='them', tag='PRON'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='or', tag='CCONJ'),
#   TaggedWord(text='any', tag='DET'),
#   TaggedWord(text='other', tag='ADJ'),
#   TaggedWord(text='phonies', tag='NOUN'),
#   TaggedWord(text="'", tag='PUNCT'),
#   TaggedWord(text='Christians', tag='PROPN'),
#   TaggedWord(text="'", tag='PUNCT'),
#   TaggedWord(text=',', tag='PUNCT'),
#   TaggedWord(text='even', tag='ADV'),
#   TaggedWord(text='if', tag='SCONJ'),
#   TaggedWord(text='they', tag='PRON'),
#   TaggedWord(text='themselves', tag='PRON'),
#   TaggedWord(text='claim', tag='VERB'),
#   TaggedWord(text='the', tag='DET'),
#   TaggedWord(text='appellation', tag='NOUN'),
#   TaggedWord(text='.', tag='PUNCT')],
#  ...]

# %%
read_tags('./data/tags')
# Out:
# ['NOUN',
#  'PUNCT',
#  'VERB',
#  'PRON',
#  'ADP',
#  'DET',
#  'PROPN',
#  'ADJ',
#  'AUX',
#  'ADV',
#  'CCONJ',
#  'PART',
#  'NUM',
#  'SCONJ',
#  'X',
#  'INTJ',
#  'SYM']

# %% [markdown]
# ### Part II: evaluation
#
# We want you to estimate tagging quality by a simple accuracy: a fraction of tag predictions that turned out to be correct - averaged over the entire training corpora.

# %%
# Data types:
TaggingQuality = collections.namedtuple('TaggingQuality', ['acc'])

def tagging_quality(ref, out):
    """
    Compute tagging quality and reutrn TaggingQuality object.
    """
    nwords = 0
    ncorrect = 0
    import itertools
    for ref_sentence, out_sentence in itertools.zip_longest(ref, out):
        for ref_word, out_word in itertools.zip_longest(ref_sentence, out_sentence):
            nwords += 1
            if ref_word.tag == out_word.tag:
                ncorrect += 1
    return ncorrect / nwords

# %% [markdown]
# ### Part III: Value and Update
#
# In order to implement two interlinked data structures:
# * __Value__ - a class that holds POS tagger's parameters. Basically an array of numbers
# * __Update__ - a class that stores updates for Value

# %%
class Value:
    def __init__(self, n):
        """
        Dense object that holds parameters.
        :param n: array length
        """
        <YOUR CODE>

    def dot(self, update):
        <YOUR CODE>

    def assign(self, other):
        """
        self = other
        other is Value.
        """
        <YOUR CODE>

    def assign_mul(self, coeff):
        """
        self = self * coeff
        coeff is float.
        """
        <YOUR CODE>

    def assign_madd(self, x, coeff):
        """
        self = self + x * coeff
        x can be either Value or Update.
        coeff is float.
        """
        <YOUR CODE>


class Update:
    """
    Sparse object that holds an update of parameters.
    """

    def __init__(self, positions=None, values=None):
        """
        positions: array of int
        values: array of float
        """
        <YOUR CODE>

    def assign_mul(self, coeff):
        """
        self = self * coeff
        coeff: float
        """
        <YOUR CODE>

    def assign_madd(self, update, coeff):
        """
        self = self + update * coeff
        coeff: float
        """
        <YOUR CODE>

# %% [markdown]
# ### Part IV: Maximum Entropy POS Tagger
# _step 1 - draw an oval; step 2 - draw the rest of the owl (c)_
#
# In this secion you will implement a simple linear model to predict POS tags.
# Make sure you [read the article](W96-0213.pdf) before you proceed.

# %%
# Data Types:
Features = Update
Hypo = collections.namedtuple('Hypo', ['prev', 'pos', 'tagged_word', 'score'])
# prev: previous Hypo
# pos: position of word (0-based)
# tagged_word: tagging of source_sentence[pos]
# score: sum of scores over edges

TaggerParams = collections.namedtuple('FeatureParams', [
    'src_window',
    'dst_order',
    'max_suffix',
    'beam_size',
    'nparams'
    ])

import cityhash
def h(x):
    """
    Compute CityHash of any object.
    Can be used to construct features.
    """
    return cityhash.CityHash64(repr(x))

# %%
class LinearModel:
    """
    A thing that computes score and gradient for given features.
    """

    def __init__(self, n):
        self._params = Value(n)

    def params(self):
        return self._params

    def score(self, features):
        """
        features: Update
        """
        return self._params.dot(features)

    def gradient(self, features, score):
        return features

# %%
class FeatureComputer:
    def __init__(self, tagger_params, source_sentence):
        <YOUR CODE>

    def compute_features(self, hypo):
        """
        Compute features for a given Hypo and return Update.
        """
        <YOUR CODE>

# %% [markdown]
# ### Part V: Beam search
#
# We can find the most likely tagging approximately using Beam Search. As everything else, it comes with a separate interface.

# %%
class BeamSearchTask:
    """
    An abstract beam search task. Can be used with beam_search() generic 
    function.
    """

    def __init__(self, tagger_params, source_sentence, model, tags):
        <YOUR CODE>

    def total_num_steps(self):
        """
        Number of hypotheses between beginning and end (number of words in
        the sentence).
        """
        <YOUR CODE>

    def beam_size(self):
        <YOUR CODE>

    def expand(self, hypo):
        """
        Given Hypo, return a list of its possible expansions.
        'hypo' might be None -- return a list of initial hypos then.

        Compute hypotheses' scores inside this function!
        """
        <YOUR CODE>

    def recombo_hash(self, hypo):
        """
        If two hypos have the same recombination hashes, they can be collapsed
        together, leaving only the hypothesis with a better score.
        """
        <YOUR CODE>


def beam_search(beam_search_task):
    """
    Return list of stacks.
    Each stack contains several hypos, sorted by score in descending 
    order (i.e. better hypos first).
    """
    <YOUR CODE>

# %%
def tag_sentences(dataset, <YOUR_PARAMS>):
    """
    Main predict function.
    Tags all sentences in dataset. Dataset is a list of TaggedSentence; while 
    tagging, ignore existing tags.
    """
    <YOUR CODE>

# %% [markdown]
# ### Part VI: Optimization objective and algorithm
#
# Once we defined our model and inference algorithm, we can define an optimization task: an object that computes loss function and its gradients w.r.t. model parameters.

# %%
class OptimizationTask:
    """
    Optimization task that can be used with sgd().
    """

    def params(self):
        """
        Parameters which are optimized in this optimization task.
        Return Value.
        """
        raise NotImplementedError()

    def loss_and_gradient(self, golden_sentence):
        """
        Return (loss, gradient) on a specific example.

        loss: float
        gradient: Update
        """
        raise NotImplementedError()


class UnstructuredPerceptronOptimizationTask(OptimizationTask):
    def __init__(self, ...):
        <YOUR CODE>

    def params(self):
        <YOUR CODE>

    def loss_and_gradient(self, golden_sentence):
        <YOUR CODE>


class StructuredPerceptronOptimizationTask(OptimizationTask):
    def __init__(self, tagger_params, tags):
        self.tagger_params = tagger_params
        self.model = LinearModel(...)
        self.tags = tags

    def params(self):
        return self.model.params()

    def loss_and_gradient(self, golden_sentence):
        # Do beam search.
        beam_search_task = BeamSearchTask(
            self.tagger_params, 
            [golden_tagged_word.text for golden_tagged_word in golden_sentence], 
            self.model, 
            self.tags
            )
        stacks = beam_search(beam_search_task)

        # Compute chain of golden hypos (and their scores!).
        golden_hypo = None
        feature_computer = ...
        for i in range(len(golden_sentence)):
            new_golden_hypo = ...
            golden_hypo = golden_hypo

        # Find where to update.
        golden_head = <YOUR CODE>
        rival_head = <YOUR CODE>

        # Compute gradient.
        grad = Update()
        while golden_head and rival_head:
            rival_features = feature_computer.compute_features(rival_head)
            grad.assign_madd(self.model.gradient(rival_features, score=None), 1)

            golden_features = feature_computer.compute_features(golden_head)
            grad.assign_madd(self.model.gradient(golden_features, score=None), -1)


            golden_head = golden_head.prev
            rival_head = rival_head.prev

        return grad

# %% [markdown]
# ### Part VII: optimizer
#
# By this point we can define a model with parameters $\theta$ and a problem that computes gradients $ \partial L \over \partial \theta $ w.r.t. model parameters.
#
# Optimization is performed by gradient descent: $ \theta := \theta - \alpha {\partial L \over \partial \theta} $
#
# In order to speed up training, we use stochastic gradient descent that operates on minibatches of data.

# %%
SGDParams = collections.namedtuple('SGDParams', [
    'epochs',
    'learning_rate',
    'minibatch_size',
    'average' # bool or int
    ])


def make_batches(dataset, minibatch_size):
    """
    Make list of batches from a list of examples.
    """
    <YOUR CODE>


def sgd(sgd_params, optimization_task, dataset, after_each_epoch_fn):
    """
    Run (averaged) SGD on a generic optimization task. Modify optimization
    task's parameters.

    After each epoch (and also before and after the whole training),
    run after_each_epoch_fn().
    """
    <YOUR CODE>

# %% [markdown]
# ### Part VIII: Training loop
#
# The train function combines everthing you used below to get new

# %%
def train(
    tags='./data/tags',
    train_dataset='./data/en-ud-train.conllu',
    dev_dataset='./data/en-ud-dev.conllu',
    model='./model.npz',
    
    sgd_epochs=15,
    sgd_learning_rate=0.01,
    sgd_minibatch_size=32,
    
    # Number of context tags in output tagging to use for features
    tagger_src_window=2,
    
    # Number of context tags in output tagging to use for features
    tagger_dst_order=3,
    
    # Maximal number of prefix/suffix letters to use for features
    tagger_max_suffix=4,
    
    # Width for beam search (0 means unstructured)
    beam_size=1,
    
    # Parameter vector size (for hashing)
    nparams= 2 * 22,
):
    """ Train a pos-tagger model and save it's parameters to :model: """

    # Beam size.
    optimization_task_cls = StructuredPerceptronOptimizationTask
    if beam_size == 0:
        beam_size = 1
        optimization_task_cls = UnstructuredPerceptronOptimizationTask

    # Parse cmdargs.
    tags = read_tags(cmdargs.tags)
    train_dataset = read_tagged_sentences(train_dataset)
    dev_dataset = read_tagged_sentences(dev_dataset)
    params = None
    if os.path.exists(cmdargs.model):
        params = pickle.load(open(cmdargs.model, 'rb'))
    sgd_params = SGDParams(
        epochs=sgd_epochs,
        learning_rate=sgd_learning_rate,
        minibatch_size=sgd_minibatch_size,
        average=sgd_average
        )
    tagger_params = TaggerParams(
        src_window=tagger_src_window,
        dst_order=tagger_dst_order,
        max_suffix=tagger_max_suffix,
        beam_size=beam_size,
        nparams=nparams
        )

    # Load optimization task
    optimization_task = optimization_task_cls(...)
    if params is not None:
        print('\n\nLoading parameters from %s\n\n' % cmdargs.model)
        optimization_task.params().assign(params)

    # Validation.
    def after_each_epoch_fn():
        model = LinearModel(cmdargs.nparams)
        model.params().assign(optimization_task.params())
        tagged_sentences = tag_sentences(dev_dataset, <YOUR_PARAMS>)
        q = pprint.pformat(tagging_quality(out=tagged_sentences, ref=dev_dataset))
        print()
        print(q)
        print()

        # Save parameters.
        print('\n\nSaving parameters to %s\n\n' % cmdargs.model)
        pickle.dump(optimization_task.params(), open(cmdargs.model, 'wb'))

    # Run SGD.
    sgd(sgd_params, optimization_task, train_dataset, after_each_epoch_fn)

# %%
# train a model with default params
train(model='./default_model.npz')

# %% [markdown]
# ### Part IX: Evaluate the trained model

# %%
def test(
    tags='./data/tags',
    dataset='./data/en-ud-dev.conllu',
    model='./model.npz',
    
    # model and inference params; see train for their description
    tagger_src_window=2,
    tagger_dst_order=3,
    tagger_max_suffix=4,
    beam_size=1,
):


    tags = read_tags(tags)
    dataset = read_tagged_sentences(dataset)
    params = pickle.load(open(model, 'rb'))
    tagger_params = TaggerParams(
        src_window=tagger_src_window,
        dst_order=tagger_dst_order,
        max_suffix=tagger_max_suffix,
        beam_size=beam_size,
        nparams=0
        )

    # Load model.
    model = LinearModel(params.values.shape[0])
    model.params().assign(params)

    # Tag all sentences.
    tagged_sentences = tag_sentences(dataset, <YOUR_PARAMS>)

    # Write tagged sentences.
    for tagged_sentence in tagged_sentences:
        write_tagged_sentence(tagged_sentence, sys.stdout)

    # Measure and print quality.
    q = pprint.pformat(tagging_quality(out=tagged_sentences, ref=dataset))
    print(q, file=sys.stderr)
# Out:
#   File "<ipython-input-4-c5d1753b0c3f>", line 30
#     tagged_sentences = tag_sentences(dataset, <YOUR_PARAMS>)
#                                               ^
# SyntaxError: invalid syntax

# %%
# test 
test(model='./default_model.npz')

# sanity chec: accuracy > 90%.

# %% [markdown]
# ### Part X: play with it
#
# _This part is optional_
#
# Once you've built something, it's only natural to test the limits of your contraption.
#
# At minumum, we want you to find out how default model accuracy depends on __beam size__
#
# To get maximum points, your model should get final quality >= 93%
#
# Any further analysis is welcome, as always.

# %%
<YOUR CODE>
